# %%
import pandas as pd

# %%
#Dataframe-dataframe is 2d data
#creating dataframe
list1=[10,20,30,40,50]
table=pd.DataFrame(list1)
print(table)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
#creating Dataframe from list of dictioneries
data=[{'a':1,'b':2},{'a':2,'b':-4,'c':8}]
table1=pd.DataFrame(data)
print(table1)
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  2 -4  8.0

# %%
# create a dictionary of Pandas Series
items = {'Bob' : pd.Series(data = [245, 25, 55], index = ['bike', 'pants', 'watch']),'Alice' : pd.Series(data = [40, 110, 500, 45], index = ['book', 'glasses', 'bike', 'pants'])}
print(items)
# Out:
# {'Bob': bike     245
# pants     25
# watch     55
# dtype: int64, 'Alice': book        40
# glasses    110
# bike       500
# pants       45
# dtype: int64}

# %%
#convert dictioneries in dataframe
shoping_carts=pd.DataFrame(items)
shoping_carts
# Out:
#            Bob  Alice
# bike     245.0  500.0
# book       NaN   40.0
# glasses    NaN  110.0
# pants     25.0   45.0
# watch     55.0    NaN

# %%
d=[{"Board/University":"Maharashtra","Year":2010,"Percentage":60},{"Board/University":"Maharashtra","Year":2012,"Percentage":45},{"Board/University":"SNDT University","Year":2015,"Percentage":59},{"Board/University":"NIIT","Year":2018,"Percentage":60}]
t1=pd.DataFrame(d)
print(t1)
# Out:
#   Board/University  Year  Percentage
# 0      Maharashtra  2010          60
# 1      Maharashtra  2012          45
# 2  SNDT University  2015          59
# 3             NIIT  2018          60

# %%
t2=pd.DataFrame(d,index=["SSC","HSC","BCA","CCC"])
print(t2)
# Out:
#     Board/University  Year  Percentage
# SSC      Maharashtra  2010          60
# HSC      Maharashtra  2012          45
# BCA  SNDT University  2015          59
# CCC             NIIT  2018          60

# %%
Marksheet=pd.DataFrame(t2)#DataFrame is Table format
Marksheet
# Out:
#     Board/University  Year  Percentage
# SSC      Maharashtra  2010          60
# HSC      Maharashtra  2012          45
# BCA  SNDT University  2015          59
# CCC             NIIT  2018          60

# %%
print('Marksheet has shape:',Marksheet.shape),#shape is gotalrow and column
print('Marksheet has dimension:',Marksheet.ndim),
print('Marksheet has a total of:',Marksheet.size),
print(),
print('The data in Marksheet is:',Marksheet.values),
print(),
print('The row index in Marksheet is:',Marksheet.index),
print(),
print('The column index in Marksheet is:',Marksheet.columns),
print(Marksheet.columns)
# Out:
# Marksheet has shape: (4, 3)
# Marksheet has dimension: 2
# Marksheet has a total of: 12
#
# The data in Marksheet is: [['Maharashtra' 2010 60]
#  ['Maharashtra' 2012 45]
#  ['SNDT University' 2015 59]
#  ['NIIT' 2018 60]]
#
# The row index in Marksheet is: Index(['SSC', 'HSC', 'BCA', 'CCC'], dtype='object')
#
# The column index in Marksheet is: Index(['Board/University', 'Year', 'Percentage'], dtype='object')
# Index(['Board/University', 'Year', 'Percentage'], dtype='object')

# %%
Marksheet.tail(2)
# Out:
#     Board/University  Year  Percentage
# BCA  SNDT University  2015          59
# CCC             NIIT  2018          60

# %%
Marksheet.head(2)
# Out:
#     Board/University  Year  Percentage
# SSC      Maharashtra  2010          60
# HSC      Maharashtra  2012          45

# %%
Marksheet.dtypes
# Out:
# Board/University    object
# Year                 int64
# Percentage           int64
# dtype: object

# %%
Marksheet.describe()
# Out:
#           Year  Percentage
# count     4.00    4.000000
# mean   2013.75   56.000000
# std       3.50    7.348469
# min    2010.00   45.000000
# 25%    2011.50   55.500000
# 50%    2013.50   59.500000
# 75%    2015.75   60.000000
# max    2018.00   60.000000

# %%
Marksheet.isnull().sum()
# Out:
# Board/University    0
# Year                0
# Percentage          0
# dtype: int64

# %%
import pandas as pd
pd.read_csv(r"C:\Users\Chandrika.jethva\Downloads\104-CHANDRIKA LOT\Salaries.csv.csv")#Just put r before your normal string. It converts a normal string to a raw string:
#pd.read_csv("C://Users//Chandrika.jethva//Downloads//104-CHANDRIKA LOT//Salaries.csv.csv")#used backward slash
# Out:
# C:\Users\Chandrika.jethva\AppData\Local\Temp\ipykernel_8584\3133164473.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(r"C:\Users\Chandrika.jethva\Downloads\104-CHANDRIKA LOT\Salaries.csv.csv")#Just put r before your normal string. It converts a normal string to a raw string:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# ...

# %%
#Reading csv file-pd.read_csv("csv file Path")
#Reading Excel file-pd.read_excel("excel file Path",sheet name="Sheet1")For Multiple sheet put sheet name
#Reading json file-pd.read_json("json file Path")
#Reading html file-pd.read_html("html URL")[0]-0 select the first table found in HTML

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylable('some numbers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.plot([1,2,3,4])
# ----> 3 plt.ylable('some numbers')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
plt.plot([1,2,3,4],[1,4,9,16],'bo')
plt.axis((0,6,0,20))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
t=np.arange(0.,6.,0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data={'a':np.arange(50),
      'b':np.random.randint(0,50,50),
      'd':np.random.randn(50)}
data['b']=data['a']+10*np.random.randn(50)
data['d']=np.abs(data['d'])*100
plt.scatter('a','b',c='c',s='d',data=data,marker="v")
plt.xlabel('entry a')
plt.xlabel('entry b')
plt.show()

# %%
import matplotlib.pyplot as plt
names=['group_a','group_b','group_c']
values=[1,10,100]
plt.figure(figsize=(9,3))
plt.subplot(131)
plt.bar(names,values)
plt.subplot(132)
plt.scatter(names,values)
plt.subplot(133)
plt.plot(names,values)
plt.suptitle('categorial plotting')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)
t1=np.arange(0.0,5.0,0.1)
t2=np.arange(0.0,5.0,0.02)
plt.figure()
plt.subplot(211)
plt.plot(t1,f(t1),'bo',t2,f(t2),'k')
plt.subplot(212)
plt.plot(t2,f(t2),np.cos(2*np.pi*t2),'r--')
plt.show()

# %%
mu,sigma=100,15
x=mu+sigma*np.random.randn(10000)
n,bins,patches=plt.hist(x,50,density=True,facecolor='g',alpha=0.75)
plt.xlabel('smarts')
plt.ylabel('probability')
plt.title('histogram of IQ')
plt.text(60,.025,r'$\mu=100,\ \sigma=15$')
plt.axis([40,160,0,0.03])
plt.grid(True)
plt.show()

# %%
ax=plt.subplot()
t=np.arange(0.0,5.0,0.01)
s=np.cos(2*np.pi*t)
line,=plt.plot(t,s,lw=2)
plt.annotate('local max',xy=(2,1),xytext=(3,1.5),arrowprops=dict(facecolor='red',shrink=0.05),)
plt.ylim(-2,2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(10)
data=np.random.normal(100,20,200)
print(data)
fig=plt.figure(figsize=(10,7))
plt.boxplot(data)
plt.show()
# Out:
# [126.63173008 114.30557949  69.09199416  99.832323   112.42671948
#   85.59828879 105.31023171 102.17097051 100.08582862  96.50799579
#  108.6605238  124.06074748  80.69868659 120.56548156 104.5726026
#  108.90275226  77.26795576 102.70273757 129.69074004  78.40390228
#   60.44543439  65.13255408 105.32140328 147.69934661 122.47382507
#  133.45244427 101.98298432 127.95992754  94.57504024 112.2640837
#   94.65365623  89.01381972 102.65416592  90.4771597  126.16946162
#  103.90026558 108.00419977  93.24735326 125.12944528  85.36060996
#  113.20463102  92.98256217  81.2113328   90.21325566  83.90817715
#   95.74604723  93.21719508 106.24339873 111.30305339  97.05159485
#   99.48189326 105.78188408  89.20241857 114.1632004  116.84449477
#  104.07161595 147.8940733  118.34917875  97.75455058  92.75639106
#   95.35635488  89.96542201 122.57570306  86.04379939  98.37755632
#   89.41407838 120.92365714  71.62887942  92.75001634  97.56188618
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy.stats import norm,uniform,binom,poisson,expon,bernoulli
#plotting the distribution
fig,axs=plt.subplots(3,2,figsize=(14,18))
fig.suptitle('real -world data distribution',fontsize=16)

#1.Normal distribution
axs(0,0).hist(df
# Out:
# Text(0.5, 0.98, 'real -world data distribution')
